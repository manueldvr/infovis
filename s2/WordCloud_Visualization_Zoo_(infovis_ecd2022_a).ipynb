# %%
# source: https://www.datacamp.com/community/tutorials/wordcloud-python

import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# % matplotlib inline

# %%
urls = ["https://biancabalzarini.github.io/infovis/s2/zoo.txt", 
"https://rfondato.github.io/infoviz/s2/zoo.txt", 
"https://jpcasal.github.io/infovis/s2/zoo.txt", 
"https://quarkzis.github.io/infovis/s2/zoo.txt", 
"https://kryari.github.io/infovis/s2/zoo.txt", 
"https://mdanielaraffom.github.io/infovis/s2/zoo.txt", 
"https://manueldvr.github.io/infovis/s2/zoo.txt", 
"https://natdebandi.github.io/infovis2/s2/zoo.txt", 
"https://hmreumann.github.io/ecd2022a/s2/zoo.txt"];

# urls = ['https://aaizemberg.github.io/infovis/data/zoo.txt']

# %%
df = pd.DataFrame({'text': []})
for url in urls:
  print(url)
  df2 = pd.read_csv(url, header=None, names=['text'])
  df = df.append( df2.dropna(), ignore_index=True )
# Out:
# https://biancabalzarini.github.io/infovis/s2/zoo.txt
# https://rfondato.github.io/infoviz/s2/zoo.txt
# https://jpcasal.github.io/infovis/s2/zoo.txt
# https://quarkzis.github.io/infovis/s2/zoo.txt
# https://kryari.github.io/infovis/s2/zoo.txt
# https://mdanielaraffom.github.io/infovis/s2/zoo.txt
# https://manueldvr.github.io/infovis/s2/zoo.txt
# https://natdebandi.github.io/infovis2/s2/zoo.txt
# https://hmreumann.github.io/ecd2022a/s2/zoo.txt

# %%
df.tail()
# Out:
#                                                   text
# 354  ______________________________________________...
# 355  ______________________________________________...
# 356                                      and networks.
# 357                              and identify outliers
# 358   take a different approach to visualizing mult...

# %%
# armo el texto para el WordCloud
text = df.filter(items=['text']).squeeze().str.cat(sep=' ')

stopwords = { 'more', 'on', 'a', 'an', 'and', 'are', 'as', 'between', 'by', 'common', 'each', 'example', 
             'for', 'have', 'in', 'is', 'it', 'one', 'of', 'often', 'or', 'other', 'our', 'such', 
             'that', 'the', 'this', 'thus', 'to', 'tour', 'use', 'we', 'while', 'with' }

# Create and generate a word cloud image:

# wordcloud = WordCloud(max_words=200, width=800,height=600, stopwords=stopwords).generate(text)
wordcloud = WordCloud(max_words=200, width=800, height=600, stopwords=stopwords, background_color="black", collocations=True).generate(text)

# Display the generated image:
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# lo grabo como un .png
#
wordcloud.to_file("wordcloud_infovis-ecd-2022-a.png")

# %%
# ?WordCloud

# %%
wordcloud.words_
# Out:
# {'data': 1.0,
#  'node': 0.4024390243902439,
#  'visualization': 0.34146341463414637,
#  'graph': 0.32926829268292684,
#  'map': 0.3170731707317073,
#  'diagram': 0.3048780487804878,
#  'time': 0.2682926829268293,
#  'chart': 0.2682926829268293,
#  'space': 0.25609756097560976,
#  'plot': 0.25609756097560976,
#  'visual': 0.23170731707317074,
#  'series': 0.23170731707317074,
#  'layout': 0.23170731707317074,
#  '________________________________________________________________________________': 0.23170731707317074,
#  'value': 0.21951219512195122,
#  'area': 0.2073170731707317,
#  'link': 0.1951219512195122,
#  'position': 0.18292682926829268,
#  'on': 0.18292682926829268,
#  'be': 0.18292682926829268,
#  'variable': 0.18292682926829268,
#  'number': 0.15853658536585366,
#  'matrix': 0.15853658536585366,
#  'line': 0.15853658536585366,
#  'technique': 0.15853658536585366,
#  'more': 0.14634146341463414,
#  'multiple': 0.13414634146341464,
#  'encoding': 0.13414634146341464,
#  'can': 0.12195121951219512,
#  'filling': 0.12195121951219512,
#  'geographic': 0.12195121951219512,
#  'distribution': 0.12195121951219512,
#  'scatter': 0.10975609756097561,
#  'dimensional': 0.10975609756097561,
#  'ADJACENCY': 0.10975609756097561,
#  'effective': 0.10975609756097561,
#  'index': 0.10975609756097561,
#  'network': 0.10975609756097561,
#  'set': 0.0975609756097561,
#  'Multivariate': 0.0975609756097561,
#  'coordinates': 0.0975609756097561,
#  'dimensions': 0.0975609756097561,
#  'pattern': 0.0975609756097561,
#  'arc': 0.0975609756097561,
#  'density': 0.0975609756097561,
#  'challenge': 0.08536585365853659,
#  'stacking': 0.08536585365853659,
#  'PARALLEL': 0.08536585365853659,
#  'HIERARCHIES': 0.08536585365853659,
#  'tree': 0.08536585365853659,
#  'than': 0.08536585365853659,
#  'features': 0.08536585365853659,
#  'interactive': 0.08536585365853659,
#  'point': 0.08536585365853659,
#  'not': 0.08536585365853659,
#  'SMALL': 0.08536585365853659,
#  'histogram': 0.08536585365853659,
#  'using': 0.08536585365853659,
#  'symbol': 0.08536585365853659,
#  'enclosure': 0.08536585365853659,
#  'through': 0.07317073170731707,
#  'Zoo': 0.07317073170731707,
#  'system': 0.07317073170731707,
#  'any': 0.07317073170731707,
#  'all': 0.07317073170731707,
#  'top': 0.07317073170731707,
#  'SPLOM': 0.07317073170731707,
#  'some': 0.07317073170731707,
#  'collection': 0.07317073170731707,
#  'two': 0.07317073170731707,
#  'hierarchy': 0.07317073170731707,
#  'related': 0.07317073170731707,
#  'underlying': 0.07317073170731707,
#  'graphical': 0.07317073170731707,
#  'bar': 0.07317073170731707,
#  'lie': 0.07317073170731707,
#  'into': 0.07317073170731707,
#  'view': 0.07317073170731707,
#  'resolution': 0.07317073170731707,
#  'form': 0.07317073170731707,
#  'Q': 0.07317073170731707,
#  'relationships': 0.07317073170731707,
#  'allows': 0.07317073170731707,
#  'correlation': 0.07317073170731707,
#  'used': 0.07317073170731707,
#  'term': 0.07317073170731707,
#  'STACKED': 0.06097560975609756,
#  'represent': 0.06097560975609756,
#  'central': 0.06097560975609756,
#  'same': 0.06097560975609756,
#  'perception': 0.06097560975609756,
#  'shows': 0.06097560975609756,
#  'based': 0.06097560975609756,
#  'negative': 0.06097560975609756,
#  'its': 0.06097560975609756,
#  'horizon': 0.06097560975609756,
#  'analysis': 0.06097560975609756,
#  'how': 0.06097560975609756,
#  'leaf': 0.06097560975609756,
#  'among': 0.06097560975609756,
#  'color': 0.06097560975609756,
#  'problem': 0.06097560975609756,
#  'distort': 0.06097560975609756,
#  'encode': 0.06097560975609756,
#  'CARTOGRAM': 0.06097560975609756,
#  'aid': 0.04878048780487805,
#  'understanding': 0.04878048780487805,
#  's': 0.04878048780487805,
#  'given': 0.04878048780487805,
#  'large': 0.04878048780487805,
#  'DNA': 0.04878048780487805,
#  'take': 0.04878048780487805,
#  'variant': 0.04878048780487805,
#  'rather': 0.04878048780487805,
#  'typically': 0.04878048780487805,
#  'seek': 0.04878048780487805,
#  'closely': 0.04878048780487805,
#  'distance': 0.04878048780487805,
#  'mapping': 0.04878048780487805,
#  'create': 0.04878048780487805,
#  'must': 0.04878048780487805,
#  'which': 0.04878048780487805,
#  'design': 0.04878048780487805,
#  'changes': 0.04878048780487805,
#  'STATISTICAL': 0.04878048780487805,
#  'important': 0.04878048780487805,
#  'exploratory': 0.04878048780487805,
#  'distributed': 0.04878048780487805,
#  'STEM': 0.04878048780487805,
#  'alternative': 0.04878048780487805,
#  'their': 0.04878048780487805,
#  'Uses': 0.04878048780487805,
#  'row': 0.04878048780487805,
#  'CHOROPLETH': 0.04878048780487805,
#  'GRADUATED': 0.04878048780487805,
#  'i': 0.04878048780487805,
#  'j': 0.04878048780487805,
#  'instead': 0.04878048780487805,
#  'has': 0.04878048780487805,
#  'produce': 0.04878048780487805,
#  'different': 0.04878048780487805,
#  'algorithm': 0.04878048780487805,
#  'http': 0.04878048780487805,
#  'region': 0.04878048780487805,
#  'cluster': 0.04878048780487805,
#  'identify': 0.04878048780487805,
#  'decision': 0.04878048780487805,
#  'reveals': 0.04878048780487805,
#  'compare': 0.04878048780487805,
#  'goal': 0.036585365853658534,
#  'leveraging': 0.036585365853658534,
#  'human': 0.036585365853658534,
#  'highly': 0.036585365853658534,
#  'tuned': 0.036585365853658534,
#  'ability': 0.036585365853658534,
#  'see': 0.036585365853658534,
#  'possible': 0.036585365853658534,
#  'extremely': 0.036585365853658534,
#  'properties': 0.036585365853658534,
#  'axes': 0.036585365853658534,
#  'blueprint': 0.036585365853658534,
#  'parent': 0.036585365853658534,
#  'addition': 0.036585365853658534,
#  'remains': 0.036585365853658534,
#  'appropriate': 0.036585365853658534,
#  'determine': 0.036585365853658534,
#  'questions': 0.036585365853658534,
#  'ask': 0.036585365853658534,
#  'most': 0.036585365853658534,
#  'interaction': 0.036585365853658534,
#  'varying': 0.036585365853658534,
#  'percentage': 0.036585365853658534,
#  'selected': 0.036585365853658534,
#  'support': 0.036585365853658534,
#  'should': 0.036585365853658534,
#  'summed': 0.036585365853658534,
#  'may': 0.036585365853658534,
#  'trends': 0.036585365853658534,
#  'atop': 0.036585365853658534,
#  'curves': 0.036585365853658534,
#  'showing': 0.036585365853658534,
#  'increasing': 0.036585365853658534,
#  'preserving': 0.036585365853658534,
#  'bands': 0.036585365853658534,
#  'layering': 0.036585365853658534,
#  'nested': 0.036585365853658534,
#  'insight': 0.036585365853658534,
#  'modeling': 0.036585365853658534,
#  'assessing': 0.036585365853658534,
#  'graphing': 0.036585365853658534,
#  'FLOW': 0.036585365853658534,
#  'placing': 0.036585365853658534,
#  'stroked': 0.036585365853658534,
#  'geographical': 0.036585365853658534,
#  'place': 0.036585365853658534,
#  'shape': 0.036585365853658534,
#  'so': 0.036585365853658534,
#  'directly': 0.036585365853658534,
#  'examples': 0.036585365853658534,
#  'dendrogram': 0.036585365853658534}

# %% [markdown]
# * *Creating a visualization requires a number of nuanced judgments.* (Crear una visualización requiere una serie de juicios matizados)
#
# * *One must determine which questions to ask, identify the appropriate data, and select effective visual encodings to map data values to graphical features such as position, size, shape, and color.* (Uno debe determinar qué preguntas hacer, identificar los datos apropiados y seleccionar codificaciones visuales efectivas para asignar valores de datos a características gráficas como posición, tamaño, forma y color.)
